# %% [markdown]
# # Python Variables Practice (Assignment 1)
#
# **Topics Covered:**
# - Variable creation
# - int, float, str, bool data types
# - Printing variables
# - f-strings

# %% [markdown]
# ## Section 1: Variable Creation & Printing

# %% [markdown]
# ### Question 1
# Create a variable to store your **age** and print it.

# %%
# write your answer

age =35

print(age)
# Out:
# 35

# %% [markdown]
# ### Question 2
# Create a variable to store the **price of a notebook** (can be a decimal value) and print it.

# %%
# write your answer
a=4.5
print("price of notebook =",4.5)
# Out:
# price of notebook = 4.5

# %% [markdown]
# ### Question 3
# Create a variable to store your **first name** and print it.

# %%
# write your answer
name=("gauri shankar")
print("first name",name)
# Out:
# first name gauri shankar

# %% [markdown]
# ### Question 4
# Create a variable to store whether you have **completed today’s class** (True/False) and print it.

# %%
# write your answer
completed_class=True
print(completed_class)
# Out:
# True

# %% [markdown]
# ### Question 5
# Create two variables:
# - one to store the **number of classes attended**
# - one to store the **average rating** (float)
# Print both.

# %%
# write your answer
classes_attended=24
rating=4.5
print("number of classes attended",{classes_attended})
print("avg rating",(rating))
# Out:
# number of classes attended {24}
# avg rating 4.5

# %% [markdown]
# ## Section 2: Printing using f-strings

# %% [markdown]
# ### Question 6
# Create variables for **name** and **age** and print:
# > My name is Rahul and I am 22 years old.

# %%
# write your answer
name="rahul"
age=22
print("my name is", name, "and" ,"i am",age,"years olg." )
# Out:
# my name is rahul and i am 22 years olg.

# %% [markdown]
# ### Question 7
# Create variables for **item name** and **price** and print:
# > The price of Pen is 10.5 rupees.

# %%
# write your answer
item_name="pen"
price=10.5
print("The price of",item_name,"is",price,"rupees.")
# Out:
# The price of pen is 10.5 rupees.

# %% [markdown]
# ### Question 8
# Create variables for **batch name** and **class completed status** and print:
# > Batch DA10 class completed status is True.

# %%
# write your answer
batch_name="DA10"
class_status=True
print("Batch",batch_name,"class completed status is",True)
# Out:
# Batch DA10 class completed status is True
