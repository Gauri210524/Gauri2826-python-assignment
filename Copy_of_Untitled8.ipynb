# %% [markdown]
# <a href="https://colab.research.google.com/github/Gauri210524/Gauri2826-python-assignment/blob/main/Copy_of_Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="aman"
age=20
price=19.99
is_student=True
print(name)
print(age)
print(price)
print(is_student)
# Out:
# aman
# 20
# 19.99
# True
